# %%
print('mlops-mlflow')
# Out:
# mlops-mlflow

# %%
print(mlflow.__version__)
# Out:
# 3.8.1

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("check localhost connection")

with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("test2",2)
# Out:
# 2026/01/14 13:43:06 INFO mlflow.tracking.fluent: Experiment with name 'check localhost connection' does not exist. Creating a new experiment.
# 🏃 View run wise-stoat-870 at: http://127.0.0.1:5000/#/experiments/1/runs/3a40bb5cd89142ce83ce59b18f854352
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test3",1)
    mlflow.log_metric("test4",2)
# Out:
# 🏃 View run fortunate-auk-995 at: http://127.0.0.1:5000/#/experiments/1/runs/da13a3e6dd164c8cacbd6dcdc0fc11aa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
